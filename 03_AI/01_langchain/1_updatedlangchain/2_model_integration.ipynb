# %% [markdown]
# ### Models Integration With OPenAI, Google Geminini and GROQ

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11', 'langchain-openai': '1.3.3'}}, output_version=None, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x10fd1a710>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x1107e1a50>, root_client=<openai.OpenAI object at 0x10fd1a110>, root_async_client=<openai.AsyncOpenAI object at 0x1107e1790>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)

# %%
# invoke the model
response = model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 12, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_11333dbddb', 'id': 'chatcmpl-Dxifq5bYXaP0bPx1iufjSjSCGJuhH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f2a8f-1dee-77e0-9581-e33ceac86997-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 30, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# chatOpenAI

from langchain_openai import ChatOpenAI
model = ChatOpenAI(model= "gpt-4.1")
reposne = model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 12, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_11333dbddb', 'id': 'chatcmpl-Dxifq5bYXaP0bPx1iufjSjSCGJuhH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f2a8f-1dee-77e0-9581-e33ceac86997-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 30, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
response.content
# Out:
# "Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today? 😊"

# %% [markdown]
# ## Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots talk primarily because of a unique combination of their vocal anatomy, high intelligence, and strong social instincts. However, it\'s crucial to understand that while they can mimic human speech with remarkable accuracy, they don\'t understand language in the same way humans do.\n\nHere\'s a breakdown of the key reasons:\n\n1.  **Unique Vocal Anatomy (The Syrinx):**\n    *   Unlike humans, who use a larynx, birds have a **syrinx** (their voice box) located at the base of the trachea.\n    *   The syrinx of parrots is particularly complex and flexible, with multiple muscles that allow for a wide range of sound production and modulation.\n    *   Their thick, muscular tongue also plays a role in shaping sounds. This combination gives them an uncanny ability to replicate the nuances of human speech.\n\n2.  **High Intelligence and Learning Ability:**\n    *   Parrots are among the most intelligent birds, with cognitive abilities comparable to some primates. They are excellent problem-solvers and highly curious.\n    *   Their brains have specialized **vocal learning centers** that are much more developed than in non-vocal learning birds. These circuits allow them to acquire and remember new sounds throughout their lives.\n    *   This intelligence enables them to associate certain sounds with specific contexts, even if they don\'t grasp the underlying meaning. For example, a parrot might say "Hello!" when someone enters the room or "Want a cracker?" when it\'s hungry.\n\n3.  **Strong Social Instincts and Flock Behavior:**\n    *   Parrots are highly social animals that live in flocks in the wild. Vocal communication is vital for maintaining flock cohesion, identifying individuals, warning of predators, and sharing information.\n    *   **In the wild:** Parrots learn specific calls and sounds from their parents and flock members to fit in and communicate effectively within their group.\n    *   **In captivity:** When a parrot lives with humans, it often perceives its human companions as its "flock." It tries to integrate itself into this new social group by mimicking the sounds it hears most often – human speech. This can be a way to bond, seek attention, or simply feel like part of the family.\n\n4.  **Environmental Stimulation and Boredom:**\n    *   Parrots are intelligent and active creatures that require a lot of mental stimulation. In a captive environment, mimicking human speech can be a form of play, exploration, and a way to alleviate boredom.\n    *   They are often rewarded (with attention, treats, or praise) for talking, which reinforces the behavior.\n\n5.  **Mimicry vs. Understanding:**\n    *   It\'s important to reiterate that parrots are primarily **mimicking** sounds. While they can learn to use words in appropriate contexts (e.g., saying "goodbye" when someone leaves), this is often based on association and conditioning rather than a true understanding of syntax, grammar, or abstract concepts.\n    *   They learn that certain sounds get a certain reaction or result in a desired outcome.\n\nIn summary, parrots talk because they have the physical apparatus, the cognitive capacity, and the social drive to mimic the sounds of their environment, particularly the speech of their human "flock" members.'

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("Why do parrots talk?")

# %% [markdown]
# ## GROQ Model Implementation

# %%
import os
from langchain.chat_models import init_chat_model


os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3-32b")
response = model.invoke("Why do parrots talk?")
response

# %%
import os 
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = ChatGroq(model="qwen/qwen3-32b")

response = model.invoke("Why do parrots talk?")
response

# %% [markdown]
# ## Streaming And Batch
#
# ### Streaming
#
# #### Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content="Artificial Intelligence (AI) represents the simulation of human intelligence processes by machines, particularly computer systems. At its core, AI aims to enable machines to learn, reason, problem-solve, perceive, and understand language, much like humans do. This revolutionary field encompasses various sub-domains, including machine learning, deep learning, natural language processing (NLP), and computer vision, each contributing to AI's expanding capabilities. Today, AI is no longer a futuristic concept but an integral part of our daily lives. From personalized recommendations on streaming platforms and sophisticated fraud detection in banking to powering autonomous vehicles and assisting medical diagnoses, AI systems are driving efficiency and innovation across virtually every sector. In healthcare, AI helps analyze complex data for drug discovery and patient care; in finance, it optimizes trading strategies and manages risk; and in manufacturing, it enhances automation and quality control. The continuous advancement of AI promises to reshape industries and redefine human-machine interaction, offering unprecedented opportunities for progress. However, its development also brings forth crucial discussions around ethics, bias, job displacement, and the need for responsible governance. As AI continues to evolve, its transformative potential remains immense, promising a future where intelligent machines collaborate with humans to tackle some of the world's most complex challenges, pushing the boundaries of what's possible.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f2aae-db07-7020-a4db-e16b8d712860-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 1143, 'total_tokens': 1156, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 884}})

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)
# Out:
# Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, especially computer systems. It involves capabilities like learning, reasoning, problem-solving, perception, and language understanding. Essentially, AI aims to enable machines to perform| tasks that typically require human cognition, adapting and improving their performance through data analysis and algorithms. Key subsets like machine learning and deep learning allow AI systems to process vast amounts of information and identify complex patterns with remarkable speed and accuracy.
#
# AI is| deeply embedded in modern life, from powering personalized recommendations and virtual assistants to driving autonomous vehicles and revolutionizing medical diagnostics. Its transformative impact is evident across industries, enhancing efficiency, accuracy, and innovation. In healthcare, AI aids in drug discovery;| in finance, it detects fraud; and in manufacturing, it streamlines production. While offering immense potential for progress and solving global challenges, AI also prompts important discussions around ethics, bias, job displacement, and the need for responsible development to ensure its| benefits are widely and equitably distributed for a positive societal future.||

# %%
model.invoke("Why do parrots have colorful feathers?")
# Out:
# AIMessage(content='Parrots are renowned for their dazzling array of colors, and there are several fascinating reasons, both evolutionary and biological, why they\'ve developed such vibrant plumage:\n\n**Evolutionary Advantages (The "Why"):**\n\n1.  **Sexual Selection and Mate Attraction:** This is perhaps the most significant reason.\n    *   **Signal of Health and Fitness:** Bright, well-maintained feathers signal to potential mates that a parrot is healthy, well-fed, free of parasites, and possesses good genes. Producing and maintaining vibrant colors can be metabolically expensive, so only the fittest individuals can do it effectively.\n    *   **Attracting a Mate:** In many parrot species, the brighter or more complex the coloration, the more attractive an individual is to the opposite sex.\n\n2.  **Species Recognition:** With over 398 species of parrots globally, many of which share similar habitats, distinct color patterns help parrots quickly identify members of their own species. This is crucial for finding appropriate mates and avoiding hybridization.\n\n3.  **Camouflage (Surprisingly!):** While a bright red or blue parrot might seem to stand out to us, consider their natural habitat: dense, tropical rainforests.\n    *   **Dappled Light:** The canopy is a mosaic of bright flowers, colorful fruits, dappled sunlight, and deep shadows. A bright green parrot can blend incredibly well into the leaves, while flashes of red or blue might mimic flowers or fruits, making them harder for predators to spot.\n    *   **Breaking Up Outline:** Complex patterns and colors can help break up a bird\'s outline, making it harder for a predator to distinguish its shape against the busy background.\n\n4.  **Social Signaling:** Within a flock, certain colors or patterns might signal dominance, age, or readiness to breed.\n\n**Biological Mechanisms (The "How"):**\n\nThe vibrant colors in parrot feathers are created by two main mechanisms:\n\n1.  **Pigments:** These are chemical compounds absorbed or produced by the bird that absorb certain wavelengths of light and reflect others.\n    *   **Psittacofulvins:** These are unique pigments found *only* in parrots and are responsible for their brilliant reds, oranges, and yellows. Unlike carotenoids (which many other birds get from their diet), parrots synthesize psittacofulvins internally.\n    *   **Melanins:** These pigments produce blacks, greys, and browns.\n    *   **Carotenoids:** While psittacofulvins are primary for reds/oranges/yellows in parrots, carotenoids obtained from diet can still contribute to feather coloration or influence the vibrancy of psittacofulvin-based colors.\n\n2.  **Structural Colors:** These colors are not due to pigments but to the microscopic structure of the feather barbs and barbules, which scatter light in specific ways.\n    *   **Blues and Greens:** Most blues and iridescent greens in parrots are structural. Tiny air pockets or layers of keratin within the feathers scatter blue light, while other wavelengths are absorbed or pass through. When this structural blue is combined with yellow pigment (either psittacofulvin or carotenoid), the result is green.\n\nIn summary, the colorful feathers of parrots are a beautiful example of how evolution leverages both genetic programming and environmental factors to create stunning displays that serve crucial roles in survival and reproduction.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f2ab0-77cd-7e60-aa28-6cbc9e522239-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 2006, 'total_tokens': 2014, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1311}})

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush= True)
# Out:
# Parrots have incredibly colorful feathers due to a fascinating combination of evolutionary pressures and unique biological mechanisms. It's| not just for show; these vibrant hues serve several crucial purposes:
#
# 1.  **Sexual Selection (Attracting Mates):**
#     *   **Signal of Health and Fitness:** Bright, well-maintained plumage is a strong indicator| of a parrot's health, nutritional status, and genetic quality. Producing and maintaining such vibrant colors requires energy and resources, so only the fittest individuals can afford to display them. Females often choose males with the most brilliant and flawless feathers, and| vice versa in some species.
#     *   **Dominance Displays:** Within a flock, more colorful or intensely colored individuals might signal their dominance or status.
#
# 2.  **Species Recognition:**
#     *   In environments with many different bird| species, including multiple parrot species, distinct color patterns help parrots quickly identify members of their own kind. This is crucial for finding appropriate mates and avoiding hybridization with other species.
#
# 3.  **Camouflage (Counter-intuitive but true!|):**
#     *   While a bright green or red parrot might seem conspicuous against a plain background, consider their natural habitat: dense tropical rainforests. These environments are full of vibrant greens from foliage, bright reds, oranges, and yellows| from fruits and flowers, and dappled sunlight.
#     *   **Disruptive Coloration:** Patches of bright colors can actually help break up a parrot's outline, making it surprisingly hard to spot amongst the visual "noise" of a| busy forest canopy. They blend into the *overall vibrancy* of their surroundings, rather than a single background color.
#
# 4.  **Communication and Social Signaling:**
#     *   Beyond mate attraction, colors can play a role in other| social interactions within a flock, such as territorial displays or signaling readiness for certain activities.
#
# 5.  **UV Vision (What *they* see):**
#     *   It's important to remember that parrots (and most birds) see| the world differently from humans. They can perceive ultraviolet (UV) light, which is invisible to us. Many parrot feathers reflect UV light, and these UV patterns can be even more important for mate choice and species recognition than the visible colors we admire|. A parrot that looks plain to us might have striking UV patterns to another parrot.
#
# ---
#
# **How do they get their colors?**
#
# Parrots achieve their stunning coloration through two primary mechanisms:
#
# 1.  **Pigments|:**
#     *   **Psittacofulvins:** These are unique pigments found only in parrots, responsible for their brilliant yellows, oranges, and reds. Unlike many other birds that get similar colors from dietary carotenoids, parrots produce ps|ittacofulvins internally.
#     *   **Melanins:** These pigments produce black, brown, and grey colors, and can also contribute to the intensity or shade of other colors.
#
# 2.  **Structural Colors:**|
#     *   Blues, greens, and iridescent (shimmering) colors are often not due to pigments, but to the microscopic structure of the feathers. Tiny, precisely arranged structures (like air bubbles or keratin layers) scatter and refract| light, creating these vibrant hues. This is why a parrot's blue or green feathers can appear to change shade or intensity depending on the angle of the light.
#
# In summary, the colorful feathers of parrots are a beautiful example of evolution| at work, serving as vital tools for survival, reproduction, and communication in their complex natural environments.||

# %% [markdown]
# ## Batch
# ### Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])

for response in responses:
    print(response)
# Out:
# content='Parrots have colorful feathers for a combination of evolutionary reasons, primarily related to their environment, social behavior, and survival strategies:\n\n1.  **Sexual Selection and Mate Attraction:** This is one of the most significant drivers.\n    *   **Display of Fitness:** Bright, vibrant, and well-maintained plumage signals to potential mates that a parrot is healthy, well-fed, free of parasites, and possesses good genes. Producing and maintaining such elaborate coloration requires energy and access to specific nutrients, making it an honest signal of quality.\n    *   **Courtship Rituals:** Many parrot species engage in elaborate courtship displays where their colors are prominently shown off to attract a mate.\n\n2.  **Species Recognition:**\n    *   Different parrot species, even those living in similar habitats, often have distinct color patterns. These patterns help parrots quickly identify members of their own species, preventing hybridization and ensuring they mate with suitable partners.\n\n3.  **Camouflage (Counter-intuitive but true!):**\n    *   While bright colors might seem to make them stand out, consider their natural habitat: dense tropical forests. These environments are not just green; they are incredibly complex and visually "noisy" with dappled sunlight, brightly colored fruits, flowers, and shadows.\n    *   **Disruptive Coloration:** A mix of bright colors can actually break up a parrot\'s outline against this busy background, making it harder for predators (like raptors from above or snakes from below) to pick them out. A bright red parrot might blend in surprisingly well with a cluster of red fruits or flowers.\n    *   **Against the Sky:** When viewed from below against a bright sky, a colorful bird can be harder to focus on than a uniformly colored one.\n\n4.  **Health Indicator:**\n    *   The pigments responsible for many of their colors (especially yellows and reds, called psittacofulvins, unique to parrots) are often derived from their diet. A parrot with access to a rich, nutritious diet will typically have more vibrant and healthy-looking plumage, further signaling its good health and foraging ability.\n\n5.  **Social Signaling:**\n    *   Within a flock, color patterns might play a role in social hierarchies or communication, though this is less understood than mate attraction.\n\n**How they get their colors:**\nParrot colors are produced in two main ways:\n*   **Pigments:** Chemical compounds within the feathers absorb certain wavelengths of light and reflect others. Parrots have unique pigments called **psittacofulvins** for their yellows, oranges, and reds. They also have **melanins** for blacks, browns, and some yellows.\n*   **Structural Colors:** Blues, greens, and iridescent hues are often created by the microscopic structure of the feathers, which scatters light in specific ways. This is why a blue feather might look different from various angles.\n\nIn summary, the vibrant plumage of parrots is a testament to millions of years of evolution, serving multiple vital roles in their survival and reproduction within their colorful tropical ecosystems.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019f2ab7-43c4-7d40-b36d-594d2261d3e3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 1718, 'total_tokens': 1726, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1085}}
# content='Airplanes fly due to a clever interplay of four fundamental forces: **lift, thrust, drag, and weight**. When these forces are balanced or manipulated in specific ways, an aircraft can take off, cruise, and land.\n\nHere\'s a breakdown of how it works:\n\n### The Four Forces of Flight\n\n1.  **Lift:**\n    *   **What it is:** The upward force that directly opposes the weight of the aircraft. It\'s what keeps the plane in the air.\n    *   **How it\'s generated:** This is the most crucial part and primarily comes from the **wings**, which are designed as **airfoils**.\n        *   **Shape (Airfoil):** A wing typically has a curved upper surface and a flatter lower surface.\n        *   **Bernoulli\'s Principle:** As air flows over the wing, the curved upper surface forces the air to travel a longer distance in the same amount of time as the air flowing under the flatter bottom. This makes the air on top move *faster*. According to Bernoulli\'s principle, faster-moving fluid has lower pressure. So, there\'s lower pressure above the wing and higher pressure below it. This pressure difference "sucks" the wing upward.\n        *   **Newton\'s Third Law:** The wing is also tilted slightly upwards relative to the oncoming air (this is called the **angle of attack**). As the wing moves through the air, it pushes air downwards. By Newton\'s Third Law (for every action, there\'s an equal and opposite reaction), the air pushes the wing upwards.\n        *   **In summary:** Both the shape of the wing and its angle of attack contribute significantly to generating lift by creating a pressure differential and deflecting air downwards. The faster the plane moves, the more air flows over the wings, and the more lift is generated.\n\n2.  **Thrust:**\n    *   **What it is:** The forward force that propels the aircraft through the air, opposing drag.\n    *   **How it\'s generated:** This comes from the **engines**.\n        *   **Jet Engines:** Work by sucking in air, compressing it, mixing it with fuel and igniting it, then expelling the hot, high-velocity exhaust gases backward. By Newton\'s Third Law, pushing gas backward propels the plane forward.\n        *   **Propeller Engines:** Propellers are essentially rotating wings. They cut through the air, creating a pressure difference that pulls the aircraft forward.\n\n3.  **Drag:**\n    *   **What it is:** The resistive force that opposes the aircraft\'s motion through the air. It\'s essentially air resistance.\n    *   **How it\'s generated:**\n        *   **Parasite Drag:** Caused by the friction of air against the aircraft\'s surfaces (skin friction) and the resistance created by the shape of the aircraft (form drag).\n        *   **Induced Drag:** A byproduct of generating lift. It\'s created by the wingtip vortices (swirling air at the wingtips).\n    *   **Goal:** Aircraft designers strive to minimize drag by making planes as aerodynamic and streamlined as possible.\n\n4.  **Weight:**\n    *   **What it is:** The downward force caused by gravity acting on the mass of the aircraft (including its structure, fuel, passengers, and cargo).\n    *   **Goal:** Lift must be greater than or equal to weight for the plane to fly and stay airborne.\n\n### How They Work Together\n\n*   **Takeoff:** The engines generate maximum **thrust**, accelerating the plane down the runway. As speed increases, the wings generate more and more **lift**. When lift exceeds **weight**, the plane leaves the ground. Thrust must also overcome **drag**.\n*   **Climb:** Thrust remains greater than drag, and lift remains greater than weight, allowing the plane to gain altitude.\n*   **Cruising (Level Flight):** The pilot adjusts engine thrust and wing angle so that **lift equals weight** and **thrust equals drag**. The plane flies at a constant altitude and speed.\n*   **Descent:** The pilot reduces thrust, causing drag to become greater than thrust, and may also reduce lift (e.g., by lowering the nose or reducing  ...
# content='**Quantum computing** is a fundamentally new type of computation that leverages the principles of **quantum mechanics** (the physics that governs the behavior of matter at the atomic and subatomic level) to solve complex problems that are intractable for classical computers.\n\nHere\'s a breakdown of what that means:\n\n### How it Differs from Classical Computing\n\nClassical computers, like your laptop or smartphone, store information in **bits**. A bit can represent either a **0** or a **1**. All operations are performed sequentially using these definite states.\n\nQuantum computers, on the other hand, use **qubits**. Qubits are the basic unit of quantum information, and they possess some unique properties that allow quantum computers to process information in ways classical computers cannot:\n\n1.  **Superposition:** Unlike a classical bit, a qubit can exist in a **superposition** of both 0 and 1 at the same time. This means a single qubit can represent a vast amount of information simultaneously. Imagine a coin spinning in the air – it\'s neither heads nor tails until it lands. A qubit is like that spinning coin, existing in all possible states until measured.\n\n2.  **Entanglement:** Qubits can become **entangled**, meaning their fates are intertwined, even when physically separated. If two qubits are entangled, measuring the state of one instantly tells you about the state of the other, no matter the distance between them. This creates incredibly powerful correlations that can be exploited for computation.\n\n3.  **Interference:** Quantum computers manipulate the probabilities of different outcomes. They use interference (much like waves reinforcing or canceling each other) to amplify the probabilities of correct answers and reduce the probabilities of incorrect ones, effectively guiding the computation towards the desired solution.\n\n### What Does This Mean for Computation?\n\nBecause of superposition and entanglement, a quantum computer with just a few hundred entangled qubits could potentially represent more information than all the atoms in the observable universe. This exponential increase in processing power allows quantum computers to explore many possibilities simultaneously, rather than one by one, which is how classical computers operate.\n\n### Potential Applications of Quantum Computing\n\nQuantum computing holds immense promise to revolutionize fields that deal with extremely complex calculations:\n\n*   **Drug Discovery and Materials Science:** Simulating molecular interactions with unprecedented accuracy, leading to the design of new drugs, catalysts, and materials with specific properties.\n*   **Cryptography:** Breaking currently used encryption methods (like RSA) and developing new, unbreakable quantum-safe encryption.\n*   **Optimization:** Solving complex optimization problems in logistics, finance, manufacturing, and supply chain management more efficiently than ever before.\n*   **Artificial Intelligence and Machine Learning:** Enhancing AI algorithms, enabling new forms of machine learning, and processing vast datasets more effectively.\n*   **Financial Modeling:** Creating more accurate and sophisticated financial models for risk assessment and market prediction.\n\n### Current Status and Challenges\n\nQuantum computing is still in its **early stages** of development. We are currently in the "NISQ era" (Noisy Intermediate-Scale Quantum), meaning we have quantum computers with a limited number of qubits that are prone to errors (noise).\n\nMajor challenges include:\n\n*   **Decoherence:** Qubits are extremely fragile and can lose their quantum properties (their superposition and entanglement) very easily due to interactions with their environment.\n*   **Error Correction:** Correcting errors in quantum systems is much more complex than in classical systems.\n*   **Scalability:** Building stable quantum computers with a large number of interconnected qubits is a significant engineering cha ...

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
],
config = {
    "max_concurrency": 5, # Limit to 5 parallel calls
}
)

for response in responses:
    print(response)
