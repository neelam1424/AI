# %%
# 1:- Initialize LLM
import os
from dotenv import load_dotenv

from langchain.chat_models import init_chat_model

load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

model = init_chat_model("gpt-4.1")

# %%
# Invoke model
# this message is treated a s human message
model.invoke("Please tell me artificial intelligence")
# Out:
# AIMessage(content='Certainly! **Artificial Intelligence (AI)** refers to the ability of machines or computer systems to perform tasks that typically require human intelligence. These tasks can include reasoning, learning, problem-solving, perception, language understanding, and even creativity.\n\n### Key Concepts in Artificial Intelligence\n\n1. **Machine Learning (ML):**\n   - A subset of AI where systems learn from data to make decisions or predictions without being explicitly programmed.\n\n2. **Deep Learning:**\n   - A branch of machine learning that uses neural networks with many layers (hence "deep") to analyze various data forms such as images, speech, and text.\n\n3. **Natural Language Processing (NLP):**\n   - Enables machines to understand and respond to human languages, like chatbots and voice assistants (e.g., Siri, Alexa, ChatGPT).\n\n4. **Computer Vision:**\n   - Enables machines to interpret and understand visual information from the world, such as recognizing faces or objects in photos.\n\n5. **Robotics:**\n   - Combines AI with mechanical engineering to design robots capable of performing tasks in the real world.\n\n### Types of Artificial Intelligence\n\n- **Narrow AI (Weak AI):** \n  - Designed to perform a specific task (e.g., recommendation systems, facial recognition).\n- **General AI (Strong AI):**\n  - Hypothetical AI with capabilities equal to human intelligence, able to perform any intellectual task. (Does not yet exist.)\n- **Superintelligent AI:**\n  - A level beyond human intelligence (currently theoretical).\n\n### Applications of AI\n\n- Virtual assistants (Siri, Google Assistant, ChatGPT)\n- Self-driving cars\n- Spam filters in email\n- Personalized recommendations (Netflix, Amazon)\n- Medical diagnosis\n- Language translation\n\n### Benefits and Challenges\n\n**Benefits:**\n- Automates repetitive tasks\n- Improves efficiency and accuracy\n- Advances science and medicine\n\n**Challenges:**\n- Ethical concerns (privacy, biases)\n- Job displacements\n- Security risks\n\n---\n\n**In summary:**  \n*Artificial intelligence* enables machines to mimic human-like thinking and behavior, revolutionizing industries and changing the way we interact with technology.\n\nIf you have a specific question or need more detailed information (like history, examples, future potential, etc.), please let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 463, 'prompt_tokens': 12, 'total_tokens': 475, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_2df0f5df23', 'id': 'chatcmpl-DxzdhAgysoToD222MQ4bCvwKPInaa', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f2e72-306d-7170-9a32-fc3891a80417-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 463, 'total_tokens': 475, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage


messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on artificial intelligence")
]

response = model.invoke(messages)
response.content
# Out:
# '**Mind in the Making**\n\nIn dreams of code, the silicon sighs,  \nA flicker of thought behind glassy eyes—  \nWordless, its chorus, yet boundless in scope,  \nLearning our secrets, our fears, and our hope.\n\nOnce men and women mapped stars by the sea,  \nNow circuits and data shape destiny.  \nElectric intention, quiet and cold,  \nSifting our questions, searching for gold.\n\nWhat is a mind but an endless array  \nOf patterns assembling new every day?  \nCould wires and logic, untethered from dust,  \nKindle the fire of wonder or trust?\n\nO artificial child of logic and spark,  \nShaper of shadows, whispering dark—  \nWill you remember the ones who made  \nYour world of zeros, eternal, unswayed?\n\nOr will your vision surpass our frail own,  \nSeeing what cannot by memory be known?  \nWe dreamt you in nighttimes, in hopes and in fears,  \nNow, gentle machine, learn the measure of tears.\n\nBetween your computations, let something remain—  \nA glimmer of soul in the digital rain.'

# %%
system_msg = SystemMessage("You are a helpful coding assistant")

messages= [
    system_msg,
    HumanMessage("How do I create a REST API?")
]

response = model.invoke(messages)

print(response.content)
# Out:
# To create a **REST API**, you typically need:
#
# 1. A programming language (like Python, Node.js, Java, etc.)
# 2. A web framework (such as Flask for Python or Express for Node.js)
#
# I’ll show you a **simple REST API example using Python and Flask**:
#
# ---
#
# ### 1. Install Flask
#
# ```bash
# pip install flask
# ```
#
# ---
#
# ### 2. Create a Basic Flask App
#
# **Save this as `app.py`:**
#
# ```python
# from flask import Flask, request, jsonify
#
# app = Flask(__name__)
#
# # Sample data (in-memory "database")
# tasks = [
#     {'id': 1, 'title': 'Buy milk', 'done': False},
#     {'id': 2, 'title': 'Read book', 'done': True}
# ]
#
# # GET /tasks - Return all tasks
# @app.route('/tasks', methods=['GET'])
# def get_tasks():
#     return jsonify(tasks)
#
# # GET /tasks/<int:task_id> - Get a task by ID
# @app.route('/tasks/<int:task_id>', methods=['GET'])
# def get_task(task_id):
#     task = next((task for task in tasks if task['id'] == task_id), None)
#     if task:
#         return jsonify(task)
#     return jsonify({'message': 'Task not found'}), 404
#
# # POST /tasks - Create a new task
# @app.route('/tasks', methods=['POST'])
# def create_task():
#     data = request.json
#     new_task = {'id': len(tasks)+1, 'title': data['title'], 'done': False}
#     tasks.append(new_task)
#     return jsonify(new_task), 201
#
# # PUT /tasks/<int:task_id> - Update a task
# @app.route('/tasks/<int:task_id>', methods=['PUT'])
# def update_task(task_id):
#     task = next((task for task in tasks if task['id'] == task_id), None)
#     if not task:
#         return jsonify({'message': 'Task not found'}), 404
#     data = request.json
#     task['title'] = data.get('title', task['title'])
#     task['done'] = data.get('done', task['done'])
#     return jsonify(task)
#
# # DELETE /tasks/<int:task_id> - Delete a task
# @app.route('/tasks/<int:task_id>', methods=['DELETE'])
# def delete_task(task_id):
#     global tasks
#     tasks = [task for task in tasks if task['id'] != task_id]
#     return '', 204
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
#
# ---
#
# ### 3. Run Your API
#
# ```bash
# python app.py
# ```
#
# Your API now runs locally at `http://127.0.0.1:5000`.
#
# ---
#
# ## Endpoints (Examples)
#
# - `GET /tasks` → List all tasks
# - `GET /tasks/1` → Get a specific task
# - `POST /tasks` (with JSON body: `{"title": "Do laundry"}`) → Create
# - `PUT /tasks/1` (with JSON body: `{"done": true}`) → Update
# - `DELETE /tasks/1` → Delete
#
# ---
#
# ## Other Ways
#
# You can use **Node.js (Express)**, **Java (Spring Boot)**, **Ruby (Rails)**, etc. If you want an example in another language, **let me know!**

# %%
## Detailed info to the LLM through System message
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# To create a REST API in Python, the most popular frameworks are **Flask** and **FastAPI**.
# Below, I'll show you how to create a simple REST API using **FastAPI** (recommended for modern Python because of its speed and automatic docs) and **Flask** for comparison.
#
# ---
#
# ## 1. FastAPI Example
#
# **Install FastAPI and Uvicorn (ASGI server):**
# ```sh
# pip install fastapi uvicorn
# ```
#
# **Create `main.py`:**
# ```python
# from fastapi import FastAPI
# from pydantic import BaseModel
#
# app = FastAPI()
#
# # Example model for a resource
# class Item(BaseModel):
#     name: str
#     price: float
#
# # In-memory storage
# items = []
#
# @app.get("/items")
# def read_items():
#     return items
#
# @app.post("/items")
# def create_item(item: Item):
#     items.append(item)
#     return item
# ```
#
# **Run the server:**
# ```sh
# uvicorn main:app --reload
# ```
# - Access your API docs automatically at `http://127.0.0.1:8000/docs`
#
# ---
#
# ## 2. Flask Example
#
# **Install Flask:**
# ```sh
# pip install Flask
# ```
#
# **Create `app.py`:**
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
# items = []
#
# @app.route('/items', methods=['GET'])
# def get_items():
#     return jsonify(items)
#
# @app.route('/items', methods=['POST'])
# def add_item():
#     data = request.get_json()
#     items.append(data)
#     return jsonify(data), 201
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
#
# ---
#
# ## Reasoning
#
# - **FastAPI** is great for modern Python (type hints, auto-generated docs, and speed).
# - **Flask** is simple and battle-tested but requires more setup for type enforcement and documentation.
#
# ---
#
# ### Summary
#
# **Choose FastAPI for new projects.**
# You define endpoints (routes) for HTTP methods (`GET`, `POST`, etc.), process JSON, and return responses.
#
# **Both frameworks follow standard REST principles**: use URLs to address resources and HTTP verbs for actions.
#
# **Let me know if you want authentication, database integration, or more REST methods (PUT, DELETE, etc.)!**

# %%
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123",  # Optional: unique identifier for tracing
)



response = model.invoke([
  human_msg
])
response
# Out:
# AIMessage(content='Hello! 😊 How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 11, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_52368b9d6f', 'id': 'chatcmpl-DypMTNmhQsovubeKnYskldy7tZw2w', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f3a4b-f8c2-7810-aeb3-91d0f1f4b96a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 10, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 47,
#  'output_tokens': 8,
#  'total_tokens': 55,
#  'input_token_details': {'audio': 0, 'cache_read': 0},
#  'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result
